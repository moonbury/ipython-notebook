# %%
# %matplotlib inline
import numpy as np
from sklearn.datasets import fetch_mldata
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import preprocessing
from sklearn.metrics import classification_report
from sklearn.cross_validation import cross_val_score
from sklearn import svm
import scipy
import pandas as pd
from sklearn import linear_model 

abalone = fetch_mldata('abalone')

abalone_df = pd.DataFrame(abalone.data, columns=['Sex','Length','Diameter','Height','Whole','Shucked','Viscera','Shell'])
groups = list(abalone.target)
#abalone_df['ring'] = pd.Series([abalone.target[k] for k in groups])
#    df_y = pd.DataFrame(d.target, columns=['Ring'])
print (max(abalone.target), min(abalone.target))
print("Describe the abalone data (X)")
print(abalone_df.describe())
print("Describe the abalone predict data(y)")
#print(abalone_df['ring'].describe())
# Out:
# (29, 1)
# Describe the abalone data (X)
#                Sex       Length     Diameter       Height        Whole  \
# count  4177.000000  4177.000000  4177.000000  4177.000000  4177.000000
# mean      1.955470     0.523992     0.407881     0.139516     0.828742
# std       0.827815     0.120093     0.099240     0.041827     0.490389
# min       1.000000     0.075000     0.055000     0.000000     0.002000
# 25%       1.000000     0.450000     0.350000     0.115000     0.441500
# 50%       2.000000     0.545000     0.425000     0.140000     0.799500
# 75%       3.000000     0.615000     0.480000     0.165000     1.153000
# max       3.000000     0.815000     0.650000     1.130000     2.825500
#
#            Shucked      Viscera        Shell
# count  4177.000000  4177.000000  4177.000000
# mean      0.359367     0.180594     0.238831
# std       0.221963     0.109614     0.139203
# min       0.001000     0.000500     0.001500
# 25%       0.186000     0.093500     0.130000
# 50%       0.336000     0.171000     0.234000
# 75%       0.502000     0.253000     0.329000
# max       1.488000     0.760000     1.005000
# Describe the abalone predict data(y)

# %%
boxplots = abalone_df.boxplot(return_type='axes')
boxplots = abalone_df.boxplot(column='Length',by='ring',return_type='axes')

# %% [raw]
# densityplot = abalone_df.plot(kind='density')

# %%
#single_distribution = abalone_df['Length'].plot(kind='hist',alpha=0.5)
colors_palette = {0:"red",1: "green",2:"blue",3:"orange",4:"orange",5:"orange",6:"orange",7:"orange",8:"orange",9:"orange"}
#colors = [colors_palette[c] for c in groups]
jet = cm = plt.get_cmap('jet') 
simple_scatterplot = abalone_df.plot(kind='scatter',x=1,y=3, colormap='terrain') #,c=colors)

# %%
hexbin = abalone_df.plot(kind='hexbin',x=1,y=3,gridsize=10)

# %%
from pandas.tools.plotting import scatter_matrix
matrix_of_scatterplots = scatter_matrix(abalone_df,alpha=0.2, figsize=(20,20),diagonal='kde')

# %%
from pandas.tools.plotting import parallel_coordinates
pl1 = parallel_coordinates(abalone_df,'groups')

# %%
C = 1 # SVM regularization parameter
clf = svm.SVC(kernel='rbf', degree=2,max_iter=-1, C=C,random_state=101)

print(type(y_train), y_train.shape)
  
clf.fit(X_train, y_train)

#scores = cross_val_score(clf,X_train,y_train,cv=2,scoring='accuracy',n_jobs=-1)

#print ("svc mean=%0.3f std=%0.3f" % (np.mean(scores),np.std(scores)))

y_pred = clf.predict(X_test)

#print("mean score: ", clf.score(X_test, y_test))
print(classification_report(y_test,y_pred))

# %%
x = [[0, 0], [1, 1], [2, 2]]
y = [0,1,2]
print(type(x), len(y), type(y), len(y))

from sklearn import linear_model 

regressor = linear_model.LinearRegression(normalize=True)
regressor.fit (a, y)
print(regressor.coef_)


#plt.scatter(, color='black')


for row in x:
    print(row)
# Out:
# <class 'list'> 3 <class 'list'> 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4ae2ab4820c9> in <module>()
#       6
#       7 regressor = linear_model.LinearRegression(normalize=True)
# ----> 8 regressor.fit (a, y)
#       9 print(regressor.coef_)
#      10
#
# NameError: name 'a' is not defined

# %%
'''

i=0
for row in y:
    
    if row < 9: 
        y[i] = 1
    if row == 9 or row == 10:
        y[i] = 2
    if row> 10: 
        y[i] = 3
    i = i + 1

from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)



print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

'''

# %%
data2 = [{'a': 1, 'b': 2}, {'a': 5, 'b': 10, 'c': 20}]
print(data2)
pd.DataFrame(data2, columns=['a', 'b'])
# Out:
# [{'b': 2, 'a': 1}, {'b': 10, 'c': 20, 'a': 5}]
#    a   b
# 0  1   2
# 1  5  10

# %%
from pandas.tools.plotting import scatter_matrix
colors_palette = {0:"red",1: "green",2:"blue"}
#colors = [colors_palette[c] for c in groups]
matrix_of_scatterplots = scatter_matrix(pd,alpha=0.2,figsize=(8,8),diagonal='kde')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-b81810528cfd> in <module>()
#       2 colors_palette = {0:"red",1: "green",2:"blue"}
#       3 #colors = [colors_palette[c] for c in groups]
# ----> 4 matrix_of_scatterplots = scatter_matrix(pd,alpha=0.2,figsize=(8,8),diagonal='kde')
#
# /usr/local/lib/python3.3/dist-packages/pandas/tools/plotting.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, **kwds)
#     229     from matplotlib.artist import setp
#     230
# --> 231     df = frame._get_numeric_data()
#     232     n = df.columns.size
#     233     fig, axes = _subplots(nrows=n, ncols=n, figsize=figsize, ax=ax,
#
# AttributeError: 'module' object has no attribute '_get_numeric_data'

# %%
print("Plot the data in 2 dimension for data visualization")
regressor = linear_model.LinearRegression()
plt.figure(figsize=(15,10))
for i in range(1,8):
    ax = plt.subplot(3,3, i)
    ax.scatter(d.data[:,i],df_y, color='black')
    regressor.fit(d.data[:,i].reshape(4177,1),d.target)
    y_pred=regressor.predict(d.data[:,i].reshape(4177,1))
    
    plt.plot(X[:,i].reshape(4177,1),y_pred)
plt.show()
