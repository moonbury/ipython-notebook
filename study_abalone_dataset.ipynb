# %%
# %matplotlib inline
import numpy as np
from sklearn.datasets import fetch_mldata
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import preprocessing
from sklearn.metrics import classification_report
from sklearn.cross_validation import cross_val_score
from sklearn import svm
import scipy
import pandas as pd
from sklearn import linear_model 

d = fetch_mldata('abalone')
df = pd.DataFrame(X, columns=['Sex','Length','Diameter','Height','Whole','Shucked','Viscera','Shell'])
df_y = pd.DataFrame(y, columns=['Ring'])

print("Describe the abalone data (X)")
print(df.describe())
print("Describe the abalone predict data(y)")
print(df_y.describe())


print("Plot the data in 2 dimension for data visualization")
regressor = linear_model.LinearRegression()
plt.figure(figsize=(15,10))
for i in range(1,8):
    ax = plt.subplot(3,3, i)
    ax.scatter(X[:,i],y, color='black')
    regressor.fit(X[:,i].reshape(4177,1),y)
    y_pred=regressor.predict(X[:,i].reshape(4177,1))
    
    plt.plot(X[:,i].reshape(4177,1),y_pred)
plt.show()
# Out:
# Describe the abalone data (X)
#                Sex       Length     Diameter       Height        Whole      Shucked      Viscera        Shell
# count  4177.000000  4177.000000  4177.000000  4177.000000  4177.000000  4177.000000  4177.000000  4177.000000
# mean      1.955470     0.523992     0.407881     0.139516     0.828742     0.359367     0.180594     0.238831
# std       0.827815     0.120093     0.099240     0.041827     0.490389     0.221963     0.109614     0.139203
# min       1.000000     0.075000     0.055000     0.000000     0.002000     0.001000     0.000500     0.001500
# 25%       1.000000     0.450000     0.350000     0.115000     0.441500     0.186000     0.093500     0.130000
# 50%       2.000000     0.545000     0.425000     0.140000     0.799500     0.336000     0.171000     0.234000
# 75%       3.000000     0.615000     0.480000     0.165000     1.153000     0.502000     0.253000     0.329000
# max       3.000000     0.815000     0.650000     1.130000     2.825500     1.488000     0.760000     1.005000
# Describe the abalone predict data(y)
#               Ring
# count  4177.000000
# mean      9.933684
# std       3.224169
# min       1.000000
# 25%       8.000000
# 50%       9.000000
# 75%      11.000000
# max      29.000000
# Plot the data in 2 dimension for data visualization

# %%
C = 1 # SVM regularization parameter
clf = svm.SVC(kernel='rbf', degree=2,max_iter=-1, C=C,random_state=101)

print(type(y_train), y_train.shape)
  
clf.fit(X_train, y_train)

#scores = cross_val_score(clf,X_train,y_train,cv=2,scoring='accuracy',n_jobs=-1)

#print ("svc mean=%0.3f std=%0.3f" % (np.mean(scores),np.std(scores)))

y_pred = clf.predict(X_test)

#print("mean score: ", clf.score(X_test, y_test))
print(classification_report(y_test,y_pred))
# Out:
# <class 'numpy.ndarray'> (3341, 1)
# <class 'numpy.ndarray'> (3341, 1)
# /usr/local/lib/python3.3/dist-packages/sklearn/svm/base.py:441: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y_ = column_or_1d(y, warn=True)
#              precision    recall  f1-score   support
#
#           1       0.68      0.75      0.71       289
#           2       0.45      0.39      0.42       280
#           3       0.63      0.64      0.63       267
#
# avg / total       0.59      0.60      0.59       836

# %%
x = [[0, 0], [1, 1], [2, 2]]
y = [0,1,2]
print(type(x), len(y), type(y), len(y))

from sklearn import linear_model 

regressor = linear_model.LinearRegression(normalize=True)
regressor.fit (a, y)
print(regressor.coef_)


#plt.scatter(, color='black')


for row in x:
    print(row)
# Out:
# <class 'list'> 3 <class 'list'> 3
# [ 0.5  0.5]
# [0, 0]
# [1, 1]
# [2, 2]

# %%
'''

i=0
for row in y:
    
    if row < 9: 
        y[i] = 1
    if row == 9 or row == 10:
        y[i] = 2
    if row> 10: 
        y[i] = 3
    i = i + 1

from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)



print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

'''

# %%
data2 = [{'a': 1, 'b': 2}, {'a': 5, 'b': 10, 'c': 20}]
print(data2)
pd.DataFrame(data2, columns=['a', 'b'])
# Out:
# [{'a': 1, 'b': 2}, {'a': 5, 'c': 20, 'b': 10}]
#    a   b
# 0  1   2
# 1  5  10
